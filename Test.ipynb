# %%
from kasir import Transaction
user = Transaction()
# Test Case 1
# Add Item 1
print("Test Case 1")
print("-----------")
user.add_item("Ayam Goreng", 2, 20_000)
print("\n")
# Add Item 2
user.add_item("Pasta Gigi", 3, 15_000)
print("\n")
print("Order Table :")
user.check_order()
user.total_price()
# Test Case 2
# Delete pasta gigi from order table
print("\n")
print("Test Case 2")
print("-----------")
user.delete_item("Pasta Gigi")
print("Order Table :")
user.check_order()
user.total_price()
# Test Case 3
# Reset all transaction
print("\n")
print("Test Case 3")
print("-----------")
user.reset_transaction()
# Test Case 4
print("\n")
print("Test Case 4")
print("-----------")
# Add Item 1
user.add_item("Ayam Goreng", 2, 20_000)
print("\n")
# Add Item 2
user.add_item("Pasta Gigi", 3, 15_000)
print("\n")
# Add Item 3
user.add_item("Mainan Mobil", 1, 200_000)
print("\n")
# Add Item 4
user.add_item("Mie Instan", 5, 3_000)
print("\n")
print("Order Table :")
user.check_order()
user.total_price()

# Test Case 5
# Update Item, JumlahBarang, dan Harga
print("\n")
print("Test Case 5")
print("-----------")
print("Order Table Before:")
user.check_order()
user.total_price()
print("\n")
# Update Item pasta gigi
user.update_item_name("Pasta Gigi", "Sabun Mandi")
# Update JumlahBarang ayam goreng
user.update_item_qty("Ayam Goreng", 3)
# Update Harga mie instan
user.update_item_price("Mie Instan", 3_500)
print("\n")
print("Order Table After:")
user.check_order()
user.total_price()
# Out:
# Test Case 1
# -----------
# Item yang Anda masukan:
# Nama Item     : Ayam Goreng
# Jumlah Barang : 2
# Harga per-Item: Rp. 20000
#
#
# Item yang Anda masukan:
# Nama Item     : Pasta Gigi
# Jumlah Barang : 3
# Harga per-Item: Rp. 15000
#
#
# Order Table :
# +----+-------------+----------------+---------+--------------+
# |    | Item        |   JumlahBarang |   Harga |   TotalHarga |
# |----+-------------+----------------+---------+--------------|
# |  0 | Ayam Goreng |              2 |   20000 |        40000 |
# |  1 | Pasta Gigi  |              3 |   15000 |        45000 |
# +----+-------------+----------------+---------+--------------+
# Total Transaksi Anda adalah Rp.85000
#
#
# Test Case 2
# -----------
# Anda telah menghapus item Pasta Gigi dari transaksi
#
# Order Table :
# +----+-------------+----------------+---------+--------------+
# |    | Item        |   JumlahBarang |   Harga |   TotalHarga |
# |----+-------------+----------------+---------+--------------|
# |  0 | Ayam Goreng |              2 |   20000 |        40000 |
# +----+-------------+----------------+---------+--------------+
# Total Transaksi Anda adalah Rp.40000
#
#
# Test Case 3
# -----------
# Semua item berhasil di delete!
# +--------+----------------+---------+
# | Item   | JumlahBarang   | Harga   |
# |--------+----------------+---------|
# +--------+----------------+---------+
#
#
# Test Case 4
# -----------
# Item yang Anda masukan:
# Nama Item     : Ayam Goreng
# Jumlah Barang : 2
# Harga per-Item: Rp. 20000
#
#
# Item yang Anda masukan:
# Nama Item     : Pasta Gigi
# Jumlah Barang : 3
# Harga per-Item: Rp. 15000
#
#
# Item yang Anda masukan:
# Nama Item     : Mainan Mobil
# Jumlah Barang : 1
# Harga per-Item: Rp. 200000
#
#
# Item yang Anda masukan:
# Nama Item     : Mie Instan
# Jumlah Barang : 5
# Harga per-Item: Rp. 3000
#
#
# Order Table :
# +----+--------------+----------------+---------+--------------+
# |    | Item         |   JumlahBarang |   Harga |   TotalHarga |
# |----+--------------+----------------+---------+--------------|
# |  0 | Ayam Goreng  |              2 |   20000 |        40000 |
# |  1 | Pasta Gigi   |              3 |   15000 |        45000 |
# |  2 | Mainan Mobil |              1 |  200000 |       200000 |
# |  3 | Mie Instan   |              5 |    3000 |        15000 |
# +----+--------------+----------------+---------+--------------+
# Total Transaksi Anda adalah Rp.285000
#
#
# Test Case 5
# -----------
# Order Table Before:
# +----+--------------+----------------+---------+--------------+
# |    | Item         |   JumlahBarang |   Harga |   TotalHarga |
# |----+--------------+----------------+---------+--------------|
# |  0 | Ayam Goreng  |              2 |   20000 |        40000 |
# |  1 | Pasta Gigi   |              3 |   15000 |        45000 |
# |  2 | Mainan Mobil |              1 |  200000 |       200000 |
# |  3 | Mie Instan   |              5 |    3000 |        15000 |
# +----+--------------+----------------+---------+--------------+
# Total Transaksi Anda adalah Rp.285000
#
#
# Anda merubah Pasta Gigi menjadi Sabun Mandi
# Anda merubah Jumlah Ayam Goreng menjadi 3
# Anda merubah harga Mie Instan menjadi 3500
#
#
# Order Table After:
# +----+--------------+----------------+---------+--------------+
# |    | Item         |   JumlahBarang |   Harga |   TotalHarga |
# |----+--------------+----------------+---------+--------------|
# |  0 | Ayam Goreng  |              3 |   20000 |        60000 |
# |  1 | Sabun Mandi  |              3 |   15000 |        45000 |
# |  2 | Mainan Mobil |              1 |  200000 |       200000 |
# |  3 | Mie Instan   |              5 |    3500 |        17500 |
# +----+--------------+----------------+---------+--------------+
# Total Transaksi Anda adalah Rp.296700
